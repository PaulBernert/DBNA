# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../_data/2020-report/data.csv")

# %%
df
# Out:
#             State            City              Region  \
# 0         Alabama      Birmingham  East South Central
# 1          Alaska       Anchorage             Pacific
# 2         Arizona            Mesa            Mountain
# 3         Arizona         Phoenix            Mountain
# 4         Arizona          Tucson            Mountain
# ..            ...             ...                 ...
# 75       Virginia  Virginia Beach      South Atlantic
# 76     Washington         Seattle             Pacific
# 77  West Virginia      Charleston      South Atlantic
# 78      Wisconsin       Milwaukee  East North Central
# 79        Wyoming        Cheyenne            Mountain
#
#     State / Providence Area (in Square Miles)  Income per Capita  Population  \
# 0                                     52419.0              22993      209880
# 1                                    663300.0              38977      291538
# 2                                    113998.0              27851      508958
# ...

# %%
def distance(a, b, w):
# Out:
#   File "<ipython-input-11-d55ab48233a4>", line 1
#     def distance(a, b):
#                        ^
# SyntaxError: unexpected EOF while parsing
